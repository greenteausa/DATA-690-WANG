# %% [markdown]
# <a href="https://colab.research.google.com/github/greenteausa/DATA-690-WANG/blob/master/Assignment_05/Assignment_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 05
# 1. Explore College Scorecard website - https://collegescorecard.ed.gov/
# 2. Explore College Scorecard Data web page - https://collegescorecard.ed.gov/data/
# 3. Download and read the documentation - https://collegescorecard.ed.gov/assets/FullDataDocumentation.pdf
# 4. Download the dataset - https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip (265MB Zip File)
# 5. Unzip the file into a folder in your personal computer (there are many files, one for each school year)
# 6. Upload the 2017-2018 school year file "MERGED2017_18_PP.csv" to Colab and create a Jupyter notebook to explore the dataset:
#     - how many colleges or rows?
#     - how many variables or columns?
#     - Look at the first 20 colleges
#     - look at the last 20 colleges
#     - Look at a random sample of 20 colleges
# 7. Since there are too many variables to explore, many of which are not interesting. Create a smaller data frame with the following 9 variables:
#     - UNITID
#     - INSTNM
#     - CITY
#     - STABBR
#     - ZIP
#     - ADM_RATE
#     - UGDS
#     - TUITIONFEE_IN
#     - MN_EARN_WNE_P10
# 8. Download and read the data dictionary file - https://collegescorecard.ed.gov/assets/CollegeScorecardDataDictionary.xlsx
# 9. Find out the definition of the above 9 variables and document the definitions in the Jupyter Notebook in a Markdown cell so that the readers of your notebook
# will know the meaning of these variables.
# 10. Explore the smaller data frame
#     - Look at the first 20 colleges
#     - look at the last 20 colleges
#     - Look at a random sample of 20 colleges
#     - Find and display UMBC
#     - Find Univ. of Maryland College Park
#     - Find and display Loyola College Maryland
#     - Find and display Johns Hopskins
#     - Calculate the min, max, and average in-state tution of the above four institutions.
# 11. Filter the smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia. Save the filtered dataset to a new file named "Five_States_Colleges.csv" for future analysis. Upload this file to your GitHub along with the notebook.
#
# **Note:** Make sure your notebook file is well organized using Markdown and code comments.

# %% [markdown]
# ## 1. Explore College Scorecard website - https://collegescorecard.ed.gov/

# %% [markdown]
# ## 2. Explore College Scorecard Data web page - https://collegescorecard.ed.gov/data/

# %% [markdown]
# ## 3. Download and read the documentation - https://collegescorecard.ed.gov/assets/FullDataDocumentation.pdf

# %%
# Import libraries
import requests
import PyPDF2 
import pandas as pd
import urllib.request
import zipfile

# %%
# I use this link as my refefrence. https://www.geeksforgeeks.org/downloading-files-web-using-python/
url = 'https://collegescorecard.ed.gov/assets/FullDataDocumentation.pdf'
r = requests.get(url, stream=True)

with open('/tmp/FullDataDocumentation.pdf', 'wb') as fd:
    for chunk in r.iter_content(chunk_size=1024):
        fd.write(chunk)

# %%
# I use the this link as my reference. https://www.geeksforgeeks.org/working-with-pdf-files-in-python/
pdfFileObj = open('/tmp/FullDataDocumentation.pdf', 'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
pageObj = pdfReader.getPage(0)
print(pageObj.extractText())
# Out:
# !"#$%&'()*+#,-)././
# )0)!"#$%&#'()*+#,-"%.'.&+%/)
# 0+(("1")2#+3"#'34
# )5%6.&.,.&+%
# 78"9"()*'.'
# )!!!"#$%#$&
# '12&34
# )55555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555).)6+4+)6%,4%&'+#7
# )55555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555).)1,,3#+,7)+'8)9#%:+,7
# )55555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555);)<&&4)5555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555);)12&34)4-")='$4%434%&'
# )55555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555)>)1,+8"?%,$
# )5555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555)@)18?%$$%&'$
# )5555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555)0/)A&$4$)5555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555)0.)B438"'4)C&87
# )555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555)0D)E%'+',%+F)1%8
# )5555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555)0G)A&?HF"4%&'
# )555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555).0)I34,&?"$)J&#)K%4F")=!)B438"'4$
# )555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555).D)L+#'%'M$
# )55555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555).N)<"H+7?"'4
# )555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555).@)1HH"'8%O)1()P%M-F%M-4$)+'8)LO,"#H4$)J#&?)4-")./0>)K",-'%,+F)9+H"#
# )5555555555555555555555555555555555555555555555555555555);;)6+4+)B&3#,"$)+'8)9"#J&#?+',")*"4#%,$
# )555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555);;)=?H&#4+'4)9#&H"#4%"$)+'8)
# Q%?%4+4%&'$)&J)E"8"#+F)6+4+
# )55555555555555555555555555555555555555555555555555555555555555555555555555);N)I:"#:%"R)&J)4-")*"+$3#"$)S$"8
# )55555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555)D.)<"J"#"',"$
# )555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555)DN))))!

# %%
pdfFileObj.close()

# %% [markdown]
# ## 4. Download the dataset - https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip (265MB Zip File)

# %%
# I use this as my reference. https://stackoverflow.com/questions/6861323/download-and-unzip-file-with-python/30327074
url = 'https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip '
filehandle, _ = urllib.request.urlretrieve(url)
zip_file_object = zipfile.ZipFile(filehandle, 'r')
first_file = zip_file_object.namelist()[0]
file = zip_file_object.open(first_file)
content = file.read()

# %% [markdown]
# ## 5. Unzip the file into a folder in your personal computer (there are many files, one for each school year)

# %%
zip_file_object.extractall()

# %%
zip_file_object.namelist()
# Out:
# ['CollegeScorecard_Raw_Data/',
#  'CollegeScorecard_Raw_Data/MERGED2011_12_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED1999_00_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2006_07_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2014_15_PP.csv',
#  'CollegeScorecard_Raw_Data/.DS_Store',
#  'CollegeScorecard_Raw_Data/MERGED2003_04_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED1996_97_PP.csv',
#  'CollegeScorecard_Raw_Data/FieldOfStudyData1516_1617_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2012_13_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2005_06_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2009_10_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2018_19_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2017_18_PP.csv',
#  'CollegeScorecard_Raw_Data/Crosswalks.zip',
#  'CollegeScorecard_Raw_Data/MERGED2000_01_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2001_02_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2016_17_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED1997_98_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED1998_99_PP.csv',
#  'CollegeScorecard_Raw_Data/data.yaml',
#  'CollegeScorecard_Raw_Data/MERGED2004_05_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2002_03_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2015_16_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2013_14_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2007_08_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2008_09_PP.csv',
#  'CollegeScorecard_Raw_Data/MERGED2010_11_PP.csv',
#  'CollegeScorecard_Raw_Data/FieldOfStudyData1415_1516_PP.csv']

# %% [markdown]
# ## 6. Upload the 2017-2018 school year file "MERGED2017_18_PP.csv" to Colab and create a Jupyter notebook to explore the dataset:
#     - how many colleges or rows?
#     - how many variables or columns?
#     - Look at the first 20 colleges
#     - look at the last 20 colleges
#     - Look at a random sample of 20 colleges

# %%
# load the 2017-2018 school year file "MERGED2017_18_PP.csv"   
MERGEN2017_18_PP = pd.read_csv('CollegeScorecard_Raw_Data/MERGED2007_08_PP.csv',low_memory=False)

# %%
# Find out how many colleges or rows?   
# Find out how many variables or columns? 
MERGEN2017_18_PP.shape
# Out:
# (6971, 1986)

# %%
# Look at the first 20 rows  
MERGEN2017_18_PP.head(20)
# Out:
#     UNITID     OPEID  OPEID6                                  INSTNM  \
# 0   100636  01230800   12308      Community College of the Air Force
# 1   100654  00100200    1002                Alabama A & M University
# 2   100663  00105200    1052     University of Alabama at Birmingham
# 3   100690  02503400   25034                      Amridge University
# 4   100706  00105500    1055     University of Alabama in Huntsville
# 5   100724  00100500    1005                Alabama State University
# 6   100751  00105100    1051               The University of Alabama
# 7   100760  00100700    1007       Central Alabama Community College
# 8   100812  00100800    1008                 Athens State University
# 9   100830  00831000    8310         Auburn University at Montgomery
# 10  100858  00100900    1009                       Auburn University
# 11  100937  00101200    1012             Birmingham-Southern College
# 12  101028  01218200   12182  Chattahoochee Valley Community College
# 13  101073  01055400   10554               Concordia College Alabama
# 14  101116  01303906   13039             South University-Montgomery
# 15  101143  00101500    1015      Enterprise State Community College
# 16  101161  00106000    1060       Coastal Alabama Community College
# 17  101189  00100300    1003                     Faulkner University
# 18  101231  00446200    4462                Gadsden Business College
# 19  101240  00101700    1017         Gadsden State Community College
#
#               CITY STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0       Montgomery     AL  36114-3011           NaN      NaN     NaN  ...
# 1           Normal     AL       35762           NaN      NaN     NaN  ...
# 2       Birmingham     AL  35294-0110           NaN      NaN     NaN  ...
# 3       Montgomery     AL  36117-3553           NaN      NaN     NaN  ...
# 4       Huntsville     AL       35899           NaN      NaN     NaN  ...
# 5       Montgomery     AL  36104-0271           NaN      NaN     NaN  ...
# 6       Tuscaloosa     AL  35487-0100           NaN      NaN     NaN  ...
# 7   Alexander City     AL       35010           NaN      NaN     NaN  ...
# 8           Athens     AL       35611           NaN      NaN     NaN  ...
# 9       Montgomery     AL  36117-3596           NaN      NaN     NaN  ...
# 10          Auburn     AL       36849           NaN      NaN     NaN  ...
# 11      Birmingham     AL       35254           NaN      NaN     NaN  ...
# 12     Phenix City     AL       36869           NaN      NaN     NaN  ...
# 13           Selma     AL       36701           NaN      NaN     NaN  ...
# 14      Montgomery     AL       36116           NaN      NaN     NaN  ...
# 15      Enterprise     AL  36330-1300           NaN      NaN     NaN  ...
# 16     Bay Minette     AL  36507-2698           NaN      NaN     NaN  ...
# 17      Montgomery     AL  36109-3390           NaN      NaN     NaN  ...
# 18    Rainbow City     AL       35906           NaN      NaN     NaN  ...
# 19         Gadsden     AL       35903           NaN      NaN     NaN  ...
#
#     OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN    UG12MN   G12MN  \
# 0                            NaN          NaN           NaN  332095.0     NaN
# 1                            NaN          NaN           NaN    5479.0  1450.0
# 2                            NaN          NaN           NaN   13531.0  6497.0
# 3                            NaN          NaN           NaN     536.0   541.0
# 4                            NaN          NaN           NaN    6740.0  1721.0
# 5                            NaN          NaN           NaN    5203.0  1380.0
# 6                            NaN          NaN           NaN   21693.0  5424.0
# 7                            NaN          NaN           NaN    3174.0     NaN
# 8                            NaN          NaN           NaN    4088.0     NaN
# 9                            NaN          NaN           NaN    5493.0  1123.0
# 10                           NaN          NaN           NaN   20535.0  4797.0
# 11                           NaN          NaN           NaN    1277.0    64.0
# 12                           NaN          NaN           NaN    3095.0     NaN
# 13                           NaN          NaN           NaN     953.0     NaN
# 14                           NaN          NaN           NaN     724.0    32.0
# 15                           NaN          NaN           NaN    3020.0     NaN
# 16                           NaN          NaN           NaN    5064.0     NaN
# 17                           NaN          NaN           NaN    3238.0   473.0
# 18                           NaN          NaN           NaN      81.0     NaN
# 19                           NaN          NaN           NaN    7854.0     NaN
#
#     SCUGFFN  POOLYRS_FTFTAIDPCT  FTFTPCTPELL_POOLED_SUPP  \
# 0       NaN                 NaN                      NaN
# 1       NaN                 NaN                      NaN
# 2       NaN                 NaN                      NaN
# 3       NaN                 NaN                      NaN
# 4       NaN                 NaN                      NaN
# 5       NaN                 NaN                      NaN
# 6       NaN                 NaN                      NaN
# 7       NaN                 NaN                      NaN
# 8       NaN                 NaN                      NaN
# 9       NaN                 NaN                      NaN
# 10      NaN                 NaN                      NaN
# 11      NaN                 NaN                      NaN
# 12      NaN                 NaN                      NaN
# 13      NaN                 NaN                      NaN
# 14      NaN                 NaN                      NaN
# 15      NaN                 NaN                      NaN
# 16      NaN                 NaN                      NaN
# 17      NaN                 NaN                      NaN
# 18      NaN                 NaN                      NaN
# 19      NaN                 NaN                      NaN
#
#     FTFTPCTFLOAN_POOLED_SUPP  SCUGFFN_POOLED
# 0                        NaN             NaN
# 1                        NaN             NaN
# 2                        NaN             NaN
# 3                        NaN             NaN
# 4                        NaN             NaN
# 5                        NaN             NaN
# 6                        NaN             NaN
# 7                        NaN             NaN
# 8                        NaN             NaN
# 9                        NaN             NaN
# 10                       NaN             NaN
# 11                       NaN             NaN
# 12                       NaN             NaN
# 13                       NaN             NaN
# 14                       NaN             NaN
# 15                       NaN             NaN
# 16                       NaN             NaN
# 17                       NaN             NaN
# 18                       NaN             NaN
# 19                       NaN             NaN
#
# [20 rows x 1986 columns]

# %%
# Look at the last 20 rows 
MERGEN2017_18_PP.tail(20)
# Out:
#         UNITID     OPEID  OPEID6  \
# 6951  37564701  02581201   25812
# 6952  37728101  03021501   30215
# 6953  38561901  03108502   31085
# 6954  38561902  03108501   31085
# 6955  40280001  02224602   22246
# 6956  40620001  02590903   25909
# 6957  40620002  02590904   25909
# 6958  40884401  02547601   25476
# 6959  40884402  02547602   25476
# 6960  42312001  03108601   31086
# 6961  42817001  03123901   31239
# 6962  42817002  03123903   31239
# 6963  43821201  00489804    4898
# 6964  43821202  00489803    4898
# 6965  43821203  00489805    4898
# 6966  44098901  02568108   25681
# 6967  44098902  02568101   25681
# 6968  44098903  02568106   25681
# 6969  44098904  02568107   25681
# 6970  44098905  02568109   25681
#
#                                                  INSTNM            CITY  \
# 6951                           CC's Cosmetology College   Oklahoma City
# 6952                           Nuvani Institute-Del Rio         Del Rio
# 6953                      Everglades University-Orlando        Maitland
# 6954                     Everglades University-Sarasota        Sarasota
# 6955                  Tri-State Cosmetology Institute 2         El Paso
# 6956           Wright Career College - Oklahoma City OK   Oklahoma City
# 6957                   Wright Career College - Tulsa OK           Tulsa
# 6958           Florida National University-South Campus           Miami
# 6959        Florida National University Training Center         Hialeah
# 6960                  Compu-Med Vocational Careers Corp           Miami
# 6961                   Southeastern College-Miami Lakes     Miami Lakes
# 6962                Southeastern College-St. Petersburg  St. Petersburg
# 6963             McCann School of Business & Technology  Hazle Township
# 6964             McCann School of Business & Technology       Lewisburg
# 6965             McCann School of Business & Technology    Dickson City
# 6966            Texas Barber College - Branch Campus #1          Dallas
# 6967            Texas Barber College - Branch Campus #2          Dallas
# 6968  Texas Barber Colleges and Hairstyling Schools ...         Houston
# 6969            Texas Barber College - Branch Campus #5         Houston
# 6970  Texas Barber Colleges and Hairstyling Schools ...          Conroe
#
#      STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 6951     OK       73112           NaN      NaN     NaN  ...
# 6952     TX  78840-5865           NaN      NaN     NaN  ...
# 6953     FL   327510000           NaN      NaN     NaN  ...
# 6954     FL   342400000           NaN      NaN     NaN  ...
# 6955     TX   799221354           NaN      NaN     NaN  ...
# 6956     OK       73159           NaN      NaN     NaN  ...
# 6957     OK       74145           NaN      NaN     NaN  ...
# 6958     FL   331752478           NaN      NaN     NaN  ...
# 6959     FL   330122478           NaN      NaN     NaN  ...
# 6960     FL       33165           NaN      NaN     NaN  ...
# 6961     FL       33015           NaN      NaN     NaN  ...
# 6962     FL       33716           NaN      NaN     NaN  ...
# 6963     PA       18202           NaN      NaN     NaN  ...
# 6964     PA       17837           NaN      NaN     NaN  ...
# 6965     PA       18519           NaN      NaN     NaN  ...
# 6966     TX       75241           NaN      NaN     NaN  ...
# 6967     TX       75228           NaN      NaN     NaN  ...
# 6968     TX       77063           NaN      NaN     NaN  ...
# 6969     TX       77022           NaN      NaN     NaN  ...
# 6970     TX       77301           NaN      NaN     NaN  ...
#
#       OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN  UG12MN  G12MN  \
# 6951                           NaN          NaN           NaN     NaN    NaN
# 6952                           NaN          NaN           NaN     NaN    NaN
# 6953                           NaN          NaN           NaN     NaN    NaN
# 6954                           NaN          NaN           NaN     NaN    NaN
# 6955                           NaN          NaN           NaN     NaN    NaN
# 6956                           NaN          NaN           NaN     NaN    NaN
# 6957                           NaN          NaN           NaN     NaN    NaN
# 6958                           NaN          NaN           NaN     NaN    NaN
# 6959                           NaN          NaN           NaN     NaN    NaN
# 6960                           NaN          NaN           NaN     NaN    NaN
# 6961                           NaN          NaN           NaN     NaN    NaN
# 6962                           NaN          NaN           NaN     NaN    NaN
# 6963                           NaN          NaN           NaN     NaN    NaN
# 6964                           NaN          NaN           NaN     NaN    NaN
# 6965                           NaN          NaN           NaN     NaN    NaN
# 6966                           NaN          NaN           NaN     NaN    NaN
# 6967                           NaN          NaN           NaN     NaN    NaN
# 6968                           NaN          NaN           NaN     NaN    NaN
# 6969                           NaN          NaN           NaN     NaN    NaN
# 6970                           NaN          NaN           NaN     NaN    NaN
#
#       SCUGFFN  POOLYRS_FTFTAIDPCT  FTFTPCTPELL_POOLED_SUPP  \
# 6951      NaN                 NaN                      NaN
# 6952      NaN                 NaN                      NaN
# 6953      NaN                 NaN                      NaN
# 6954      NaN                 NaN                      NaN
# 6955      NaN                 NaN                      NaN
# 6956      NaN                 NaN                      NaN
# 6957      NaN                 NaN                      NaN
# 6958      NaN                 NaN                      NaN
# 6959      NaN                 NaN                      NaN
# 6960      NaN                 NaN                      NaN
# 6961      NaN                 NaN                      NaN
# 6962      NaN                 NaN                      NaN
# 6963      NaN                 NaN                      NaN
# 6964      NaN                 NaN                      NaN
# 6965      NaN                 NaN                      NaN
# 6966      NaN                 NaN                      NaN
# 6967      NaN                 NaN                      NaN
# 6968      NaN                 NaN                      NaN
# 6969      NaN                 NaN                      NaN
# 6970      NaN                 NaN                      NaN
#
#       FTFTPCTFLOAN_POOLED_SUPP  SCUGFFN_POOLED
# 6951                       NaN             NaN
# 6952                       NaN             NaN
# 6953                       NaN             NaN
# 6954                       NaN             NaN
# 6955                       NaN             NaN
# 6956                       NaN             NaN
# 6957                       NaN             NaN
# 6958                       NaN             NaN
# 6959                       NaN             NaN
# 6960                       NaN             NaN
# 6961                       NaN             NaN
# 6962                       NaN             NaN
# 6963                       NaN             NaN
# 6964                       NaN             NaN
# 6965                       NaN             NaN
# 6966                       NaN             NaN
# 6967                       NaN             NaN
# 6968                       NaN             NaN
# 6969                       NaN             NaN
# 6970                       NaN             NaN
#
# [20 rows x 1986 columns]

# %%
# Look at a random sample of 20 rows    
MERGEN2017_18_PP.sample(20)
# Out:
#         UNITID     OPEID  OPEID6  \
# 3538    212391  00966600    9666
# 6949  24366501  00394601    3946
# 6475    447227  02300105   23001
# 4666    246415  02326000   23260
# 5118    382911  00357401    3574
# 218     109651  00111600    1116
# 2697    191199  00753200    7532
# 3557    212975  02536600   25366
# 5011    375841  03022600   30226
# 3949    221856  00352400    3524
# 3718    216463  02299300   22993
# 1285    150604  00179800    1798
# 3678    215585  01038800   10388
# 5195    397270  03308300   33083
# 4140    228802  01116300   11163
# 919     138275  00884800    8848
# 4801    364618  02545000   25450
# 2706    191393  02265204   22652
# 4730    260372  02532200   25322
# 916     137962  03028200   30282
#
#                                                  INSTNM         CITY STABBR  \
# 3538                       Empire Beauty School-Reading      Reading     PA
# 6949   University of the Virgin Islands-Albert A. Sheen    St. Croix     VI
# 6475                         Everest College-Earth City   Earth City     MO
# 4666  UCAS University of Cosmetology Arts & Sciences...  San Antonio     TX
# 5118        Southwest Collegiate Institute for the Deaf   Big Spring     TX
# 218                        Art Center College of Design     Pasadena     CA
# 2697                     Finger Lakes Community College  Canandaigua     NY
# 3557                   Commonwealth Technical Institute    Johnstown     PA
# 5011   Le Cordon Bleu College of Culinary Arts-Portland     Portland     OR
# 3949                        Tennessee Temple University  Chattanooga     TN
# 3718              Trinity Episcopal School for Ministry     Ambridge     PA
# 1285                                   Franklin College     Franklin     IN
# 3678                     Reading Area Community College      Reading     PA
# 5195                                 Bristol University      Anaheim     CA
# 4140                   The University of Texas at Tyler        Tyler     TX
# 919                                   Warner University   Lake Wales     FL
# 4801  Lawrence County Career and Technical Center-Pr...   New Castle     PA
# 2706                          Global Business Institute     New York     NY
# 4730                 Lac Courte Oreilles Ojibwe College      Hayward     WI
# 916                          Trinity College of Florida      Trinity     FL
#
#              ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 3538       19605           NaN      NaN     NaN  ...
# 6949       00850           NaN      NaN     NaN  ...
# 6475       63045           NaN      NaN     NaN  ...
# 4666       78201           NaN      NaN     NaN  ...
# 5118  79720-7298           NaN      NaN     NaN  ...
# 218        91103           NaN      NaN     NaN  ...
# 2697  14424-8395           NaN      NaN     NaN  ...
# 3557  15905-3092           NaN      NaN     NaN  ...
# 5011  97205-2793           NaN      NaN     NaN  ...
# 3949  37404-3587           NaN      NaN     NaN  ...
# 3718  15003-2397           NaN      NaN     NaN  ...
# 1285  46131-2623           NaN      NaN     NaN  ...
# 3678       19602           NaN      NaN     NaN  ...
# 5195  92806-6198           NaN      NaN     NaN  ...
# 4140  75799-6699           NaN      NaN     NaN  ...
# 919   33859-8797           NaN      NaN     NaN  ...
# 4801  16101-5099           NaN      NaN     NaN  ...
# 2706       10035           NaN      NaN     NaN  ...
# 4730       54843           NaN      NaN     NaN  ...
# 916   34655-4401           NaN      NaN     NaN  ...
#
#       OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN  UG12MN   G12MN  \
# 3538                           NaN          NaN           NaN   228.0     NaN
# 6949                           NaN          NaN           NaN     NaN     NaN
# 6475                           NaN          NaN           NaN   734.0     NaN
# 4666                           NaN          NaN           NaN   196.0     NaN
# 5118                           NaN          NaN           NaN   131.0     NaN
# 218                            NaN          NaN           NaN  1968.0   173.0
# 2697                           NaN          NaN           NaN  6882.0     NaN
# 3557                           NaN          NaN           NaN   426.0     NaN
# 5011                           NaN          NaN           NaN  1647.0     NaN
# 3949                           NaN          NaN           NaN   576.0   167.0
# 3718                           NaN          NaN           NaN     NaN   398.0
# 1285                           NaN          NaN           NaN  1066.0     NaN
# 3678                           NaN          NaN           NaN  6850.0     NaN
# 5195                           NaN          NaN           NaN    37.0     NaN
# 4140                           NaN          NaN           NaN  5679.0  1582.0
# 919                            NaN          NaN           NaN  1132.0   137.0
# 4801                           NaN          NaN           NaN    82.0     NaN
# 2706                           NaN          NaN           NaN   701.0     NaN
# 4730                           NaN          NaN           NaN   787.0     NaN
# 916                            NaN          NaN           NaN   211.0     NaN
#
#       SCUGFFN  POOLYRS_FTFTAIDPCT  FTFTPCTPELL_POOLED_SUPP  \
# 3538      NaN                 NaN                      NaN
# 6949      NaN                 NaN                      NaN
# 6475      NaN                 NaN                      NaN
# 4666      NaN                 NaN                      NaN
# 5118      NaN                 NaN                      NaN
# 218       NaN                 NaN                      NaN
# 2697      NaN                 NaN                      NaN
# 3557      NaN                 NaN                      NaN
# 5011      NaN                 NaN                      NaN
# 3949      NaN                 NaN                      NaN
# 3718      NaN                 NaN                      NaN
# 1285      NaN                 NaN                      NaN
# 3678      NaN                 NaN                      NaN
# 5195      NaN                 NaN                      NaN
# 4140      NaN                 NaN                      NaN
# 919       NaN                 NaN                      NaN
# 4801      NaN                 NaN                      NaN
# 2706      NaN                 NaN                      NaN
# 4730      NaN                 NaN                      NaN
# 916       NaN                 NaN                      NaN
#
#       FTFTPCTFLOAN_POOLED_SUPP  SCUGFFN_POOLED
# 3538                       NaN             NaN
# 6949                       NaN             NaN
# 6475                       NaN             NaN
# 4666                       NaN             NaN
# 5118                       NaN             NaN
# 218                        NaN             NaN
# 2697                       NaN             NaN
# 3557                       NaN             NaN
# 5011                       NaN             NaN
# 3949                       NaN             NaN
# 3718                       NaN             NaN
# 1285                       NaN             NaN
# 3678                       NaN             NaN
# 5195                       NaN             NaN
# 4140                       NaN             NaN
# 919                        NaN             NaN
# 4801                       NaN             NaN
# 2706                       NaN             NaN
# 4730                       NaN             NaN
# 916                        NaN             NaN
#
# [20 rows x 1986 columns]

# %% [markdown]
# ## 7. Since there are too many variables to explore, many of which are not interesting. Create a smaller data frame with the following 9 variables:
#     - UNITID
#     - INSTNM
#     - CITY
#     - STABBR
#     - ZIP
#     - ADM_RATE
#     - UGDS
#     - TUITIONFEE_IN
#     - MN_EARN_WNE_P10

# %%
MERGEN2017_18_PP[['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10']]
# Out:
#         UNITID                                             INSTNM        CITY  \
# 0       100636                 Community College of the Air Force  Montgomery
# 1       100654                           Alabama A & M University      Normal
# 2       100663                University of Alabama at Birmingham  Birmingham
# 3       100690                                 Amridge University  Montgomery
# 4       100706                University of Alabama in Huntsville  Huntsville
# ...        ...                                                ...         ...
# 6966  44098901            Texas Barber College - Branch Campus #1      Dallas
# 6967  44098902            Texas Barber College - Branch Campus #2      Dallas
# 6968  44098903  Texas Barber Colleges and Hairstyling Schools ...     Houston
# 6969  44098904            Texas Barber College - Branch Campus #5     Houston
# 6970  44098905  Texas Barber Colleges and Hairstyling Schools ...      Conroe
#
#      STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN    MN_EARN_WNE_P10
# 0        AL  36114-3011       NaN      0.0            NaN                NaN
# 1        AL       35762    0.3182   4704.0         4072.0              37800
# 2        AL  35294-0110    0.8778  10381.0         4208.0              47700
# 3        AL  36117-3553       NaN    343.0         6240.0  PrivacySuppressed
# 4        AL       35899    0.8800   5562.0         5216.0              53400
# ...     ...         ...       ...      ...            ...                ...
# 6966     TX       75241       NaN      NaN            NaN              22400
# 6967     TX       75228       NaN      NaN            NaN              22400
# 6968     TX       77063       NaN      NaN            NaN              22400
# 6969     TX       77022       NaN      NaN            NaN              22400
# 6970     TX       77301       NaN      NaN            NaN              22400
#
# [6971 rows x 9 columns]

# %% [markdown]
# ## 8. Download and read the data dictionary file - https://collegescorecard.ed.gov/assets/CollegeScorecardDataDictionary.xlsx

# %%
import urllib
dls = "https://collegescorecard.ed.gov/assets/CollegeScorecardDataDictionary.xlsx"
#urllib.urlretrieve(dls, "test.xls")
urllib.request.urlretrieve(dls, "CollegeScorecardDataDictionary.xlsx")
# Out:
# ('CollegeScorecardDataDictionary.xlsx',
#  <http.client.HTTPMessage at 0x11de165d0>)

# %%
xls = pd.ExcelFile('CollegeScorecardDataDictionary.xlsx')

# Now you can list all sheets in the file
xls.sheet_names
# ['house', 'house_extra', ...]

# to read just one sheet to dataframe:
df = pd.read_excel('CollegeScorecardDataDictionary.xlsx', sheet_name = "institution_data_dictionary")

# %%
df
# Out:
#                                    NAME OF DATA ELEMENT dev-category  \
# 0                               Unit ID for institution         root
# 1                        8-digit OPE ID for institution         root
# 2                        6-digit OPE ID for institution         root
# 3                                      Institution name       school
# 4                                                  City       school
# ...                                                 ...          ...
# 2238  Number of full-time, first-time degree/certifi...      student
# 2239  Years used for rolling averages of FTFTPCTPELL...          aid
# 2240  Percentage of full-time, first-time degree/cer...          aid
# 2241  Percentage of full-time, first-time degree/cer...          aid
# 2242  Number of full-time, first-time degree/certifi...      student
#
#                                 developer-friendly name API data type  \
# 0                                                    id       integer
# 1                                               ope8_id        string
# 2                                               ope6_id        string
# 3                                                  name  autocomplete
# 4                                                  city  autocomplete
# ...                                                 ...           ...
# 2238  ftft_undergrads_with_pell_grant_or_federal_stu...       integer
# 2239            ftft_undergrads_pell_federal_loan_years       integer
# 2240                        ftft_pell_grant_rate_pooled         float
# 2241                      ftft_federal_loan_rate_pooled         float
# 2242  ftft_undergrads_with_pell_grant_or_federal_stu...       integer
#
#                  VARIABLE NAME  VALUE LABEL SOURCE  \
# 0                       UNITID    NaN   NaN  IPEDS
# 1                        OPEID    NaN   NaN  IPEDS
# 2                       OPEID6    NaN   NaN  IPEDS
# 3                       INSTNM    NaN   NaN  IPEDS
# 4                         CITY    NaN   NaN  IPEDS
# ...                        ...    ...   ...    ...
# 2238                   SCUGFFN    NaN   NaN  IPEDS
# 2239        POOLYRS_FTFTAIDPCT    NaN   NaN  IPEDS
# 2240   FTFTPCTPELL_POOLED_SUPP    NaN   NaN  IPEDS
# 2241  FTFTPCTFLOAN_POOLED_SUPP    NaN   NaN  IPEDS
# 2242            SCUGFFN_POOLED    NaN   NaN  IPEDS
#
#                                                   NOTES
# 0                       Shown/used on consumer website.
# 1                       Shown/used on consumer website.
# 2                       Shown/used on consumer website.
# 3                       Shown/used on consumer website.
# 4                       Shown/used on consumer website.
# ...                                                 ...
# 2238                                                NaN
# 2239                                                NaN
# 2240  Shown/used on consumer website;    The proport...
# 2241  Shown/used on consumer website;    The proport...
# 2242                                                NaN
#
# [2243 rows x 9 columns]

# %%
# reimport the data with above 12 columns (ignore all other variables)
df_new = pd.read_csv('CollegeScorecard_Raw_Data/MERGED2007_08_PP.csv', usecols = ['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10'], low_memory = False)
df_new
# Out:
#         UNITID                                             INSTNM        CITY  \
# 0       100636                 Community College of the Air Force  Montgomery
# 1       100654                           Alabama A & M University      Normal
# 2       100663                University of Alabama at Birmingham  Birmingham
# 3       100690                                 Amridge University  Montgomery
# 4       100706                University of Alabama in Huntsville  Huntsville
# ...        ...                                                ...         ...
# 6966  44098901            Texas Barber College - Branch Campus #1      Dallas
# 6967  44098902            Texas Barber College - Branch Campus #2      Dallas
# 6968  44098903  Texas Barber Colleges and Hairstyling Schools ...     Houston
# 6969  44098904            Texas Barber College - Branch Campus #5     Houston
# 6970  44098905  Texas Barber Colleges and Hairstyling Schools ...      Conroe
#
#      STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN    MN_EARN_WNE_P10
# 0        AL  36114-3011       NaN      0.0            NaN                NaN
# 1        AL       35762    0.3182   4704.0         4072.0              37800
# 2        AL  35294-0110    0.8778  10381.0         4208.0              47700
# 3        AL  36117-3553       NaN    343.0         6240.0  PrivacySuppressed
# 4        AL       35899    0.8800   5562.0         5216.0              53400
# ...     ...         ...       ...      ...            ...                ...
# 6966     TX       75241       NaN      NaN            NaN              22400
# 6967     TX       75228       NaN      NaN            NaN              22400
# 6968     TX       77063       NaN      NaN            NaN              22400
# 6969     TX       77022       NaN      NaN            NaN              22400
# 6970     TX       77301       NaN      NaN            NaN              22400
#
# [6971 rows x 9 columns]

# %%
df_new.isnull().sum()
# Out:
# UNITID                0
# INSTNM                0
# CITY                  0
# STABBR                0
# ZIP                   0
# ADM_RATE           4117
# UGDS                517
# TUITIONFEE_IN      2789
# MN_EARN_WNE_P10     749
# dtype: int64

# %% [markdown]
# ## 9. Find out the definition of the above 9 variables and document the definitions in the Jupyter Notebook in a Markdown cell so that the readers of your notebook will know the meaning of these variables.

# %% [markdown]
# ###
# UNITID: Unit ID for institution.
#
# INSTNM: Institution name.
#
# CITY: City.
#
# STABBR:
#
# ZIP: ZIP code.
#
# ADM_RATE: Admission rate.
#
# UGDS: Enrollment of undergraduate certificate/degree-seeking students.
#
# TUITIONFEE_IN:In-state tuition and fees.
#
# MN_EARN_WNE_P10: Mean earnings of students working and not enrolled 10 years after entry.

# %% [markdown]
# ## 10. Explore the smaller data frame
#     - Look at the first 20 colleges
#     - look at the last 20 colleges
#     - Look at a random sample of 20 colleges
#     - Find and display UMBC
#     - Find Univ. of Maryland College Park
#     - Find and display Loyola College Maryland
#     - Find and display Johns Hopskins
#     - Calculate the min, max, and average in-state tution of the above four institutions.

# %% [markdown]
# ###  Look at the first 20 colleges

# %%
df_new.head(20)
# Out:
#     UNITID                                  INSTNM            CITY STABBR  \
# 0   100636      Community College of the Air Force      Montgomery     AL
# 1   100654                Alabama A & M University          Normal     AL
# 2   100663     University of Alabama at Birmingham      Birmingham     AL
# 3   100690                      Amridge University      Montgomery     AL
# 4   100706     University of Alabama in Huntsville      Huntsville     AL
# 5   100724                Alabama State University      Montgomery     AL
# 6   100751               The University of Alabama      Tuscaloosa     AL
# 7   100760       Central Alabama Community College  Alexander City     AL
# 8   100812                 Athens State University          Athens     AL
# 9   100830         Auburn University at Montgomery      Montgomery     AL
# 10  100858                       Auburn University          Auburn     AL
# 11  100937             Birmingham-Southern College      Birmingham     AL
# 12  101028  Chattahoochee Valley Community College     Phenix City     AL
# 13  101073               Concordia College Alabama           Selma     AL
# 14  101116             South University-Montgomery      Montgomery     AL
# 15  101143      Enterprise State Community College      Enterprise     AL
# 16  101161       Coastal Alabama Community College     Bay Minette     AL
# 17  101189                     Faulkner University      Montgomery     AL
# 18  101231                Gadsden Business College    Rainbow City     AL
# 19  101240         Gadsden State Community College         Gadsden     AL
#
#            ZIP  ADM_RATE     UGDS  TUITIONFEE_IN    MN_EARN_WNE_P10
# 0   36114-3011       NaN      0.0            NaN                NaN
# 1        35762    0.3182   4704.0         4072.0              37800
# 2   35294-0110    0.8778  10381.0         4208.0              47700
# 3   36117-3553       NaN    343.0         6240.0  PrivacySuppressed
# 4        35899    0.8800   5562.0         5216.0              53400
# 5   36104-0271    0.4159   4647.0         4508.0              33300
# 6   35487-0100    0.6386  20910.0         5700.0              53100
# 7        35010       NaN   2177.0         2700.0              31600
# 8        35611       NaN   2858.0            NaN              44000
# 9   36117-3596    0.9174   4352.0         5010.0              40000
# 10       36849    0.6897  19799.0         5834.0              55300
# 11       35254    0.6595   1339.0        24300.0              55400
# 12       36869       NaN   1579.0         2700.0              31900
# 13       36701       NaN    555.0         6826.0              26700
# 14       36116    0.9022    504.0        12570.0              36500
# 15  36330-1300       NaN   2020.0         2700.0              31900
# 16  36507-2698       NaN   3521.0         2790.0              32300
# 17  36109-3390    0.5896   2478.0        12000.0              42200
# 18       35906    0.9091     42.0            NaN              23600
# 19       35903       NaN   5295.0         2700.0              31700

# %% [markdown]
# ### look at the last 20 colleges

# %%
df_new.tail(20)
# Out:
#         UNITID                                             INSTNM  \
# 6951  37564701                           CC's Cosmetology College
# 6952  37728101                           Nuvani Institute-Del Rio
# 6953  38561901                      Everglades University-Orlando
# 6954  38561902                     Everglades University-Sarasota
# 6955  40280001                  Tri-State Cosmetology Institute 2
# 6956  40620001           Wright Career College - Oklahoma City OK
# 6957  40620002                   Wright Career College - Tulsa OK
# 6958  40884401           Florida National University-South Campus
# 6959  40884402        Florida National University Training Center
# 6960  42312001                  Compu-Med Vocational Careers Corp
# 6961  42817001                   Southeastern College-Miami Lakes
# 6962  42817002                Southeastern College-St. Petersburg
# 6963  43821201             McCann School of Business & Technology
# 6964  43821202             McCann School of Business & Technology
# 6965  43821203             McCann School of Business & Technology
# 6966  44098901            Texas Barber College - Branch Campus #1
# 6967  44098902            Texas Barber College - Branch Campus #2
# 6968  44098903  Texas Barber Colleges and Hairstyling Schools ...
# 6969  44098904            Texas Barber College - Branch Campus #5
# 6970  44098905  Texas Barber Colleges and Hairstyling Schools ...
#
#                 CITY STABBR         ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 6951   Oklahoma City     OK       73112       NaN   NaN            NaN
# 6952         Del Rio     TX  78840-5865       NaN   NaN            NaN
# 6953        Maitland     FL   327510000       NaN   NaN        11720.0
# 6954        Sarasota     FL   342400000       NaN   NaN        11720.0
# 6955         El Paso     TX   799221354       NaN   NaN            NaN
# 6956   Oklahoma City     OK       73159       NaN   NaN         8160.0
# 6957           Tulsa     OK       74145       NaN   NaN         8160.0
# 6958           Miami     FL   331752478       NaN   NaN        11720.0
# 6959         Hialeah     FL   330122478       NaN   NaN        11720.0
# 6960           Miami     FL       33165       NaN   NaN            NaN
# 6961     Miami Lakes     FL       33015       NaN   NaN        13256.0
# 6962  St. Petersburg     FL       33716       NaN   NaN        13256.0
# 6963  Hazle Township     PA       18202       NaN   NaN        10896.0
# 6964       Lewisburg     PA       17837       NaN   NaN        10896.0
# 6965    Dickson City     PA       18519       NaN   NaN        10896.0
# 6966          Dallas     TX       75241       NaN   NaN            NaN
# 6967          Dallas     TX       75228       NaN   NaN            NaN
# 6968         Houston     TX       77063       NaN   NaN            NaN
# 6969         Houston     TX       77022       NaN   NaN            NaN
# 6970          Conroe     TX       77301       NaN   NaN            NaN
#
#         MN_EARN_WNE_P10
# 6951              18300
# 6952              19800
# 6953  PrivacySuppressed
# 6954  PrivacySuppressed
# 6955              18900
# 6956              21800
# 6957              21800
# 6958              30800
# 6959              30800
# 6960              21100
# 6961              41200
# 6962              41200
# 6963              27000
# 6964              27000
# 6965              27000
# 6966              22400
# 6967              22400
# 6968              22400
# 6969              22400
# 6970              22400

# %% [markdown]
# ###  Look at a random sample of 20 colleges

# %%
df_new.sample(20)
# Out:
#         UNITID                                         INSTNM           CITY  \
# 2500    184694  Fairleigh Dickinson University-Florham Campus        Madison
# 5548    420194                      American National College        Houston
# 6848  13180327          Strayer University-Shelby Oaks Campus        Memphis
# 1944    168218                              Wellesley College      Wellesley
# 693     128896                     Cortiva Institute-Cromwell       Cromwell
# 2889    196291                          SUNY Maritime College   Throggs Neck
# 4297    233611                   Southern Virginia University    Buena Vista
# 1739    161563                                 Thomas College     Waterville
# 4167    229799                            Weatherford College    Weatherford
# 1207    147703                   Northern Illinois University         Dekalb
# 4346    235158                  Paroba College of Cosmetology        Everett
# 6577    448460                ITT Technical Institute-Dunmore        Dunmore
# 4841    366395               Suffolk County Community College         Selden
# 1549    156648  Elizabethtown Community and Technical College  Elizabethtown
# 4357    235495                      Interface College-Spokane        Spokane
# 5498    418612                    Hazleton Area Career Center     Hazle TWP.
# 4280    233037                  Paul D Camp Community College       Franklin
# 2990    198835                        Lenoir-Rhyne University        Hickory
# 136     106281                         ABC Beauty College Inc    Arkadelphia
# 2131    174428                   Normandale Community College    Bloomington
#
#      STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN    MN_EARN_WNE_P10
# 2500     NJ       07940    0.6256   2470.0        28778.0              55800
# 5548     TX  77069-4611       NaN    141.0            NaN              26300
# 6848     TN       38134       NaN      NaN        11712.0              57800
# 1944     MA  02481-8203    0.3570   2247.0        34994.0              69800
# 693      CT       06416    0.7813    228.0        12350.0              34800
# 2889     NY  10465-4198    0.7226   1326.0         6049.0              78200
# 4297     VA       24416    0.4280    693.0        16500.0                NaN
# 1739     ME  04901-5097    0.9318    765.0        18710.0              38200
# 4167     TX  76086-5699       NaN   4128.0         1680.0              33200
# 1207     IL  60115-2828    0.6952  18915.0         8588.0              51500
# 4346     WA       98203       NaN    138.0            NaN  PrivacySuppressed
# 6577     PA       18512    0.3138    149.0        15600.0              44900
# 4841     NY  11784-2899       NaN  19415.0         4046.0              43800
# 1549     KY  42701-3081       NaN   4426.0         2760.0              35100
# 4357     WA       99201    0.5926    102.0            NaN              25000
# 5498     PA       18202       NaN     37.0            NaN  PrivacySuppressed
# 4280     VA       23851       NaN    963.0         2405.0              26200
# 2990     NC       28601    0.8350   1366.0        21580.0              47000
# 136      AR       71923       NaN     39.0            NaN  PrivacySuppressed
# 2131     MN  55431-4399       NaN   8426.0         4512.0              42600

# %% [markdown]
# ### Find and display UMBC

# %%
df_new[df_new['INSTNM'].str.contains('Baltimore County')&df_new['INSTNM'].str.contains('Maryland')]
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1779  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN MN_EARN_WNE_P10
# 1779  21250    0.6895  9304.0         8708.0           58000

# %% [markdown]
# ###  Find Univ. of Maryland College Park

# %%
df_new[df_new['INSTNM'].str.contains('Maryland-College Park')]
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1780  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN MN_EARN_WNE_P10
# 1780    0.4704  25295.0         7969.0           66700

# %% [markdown]
# ### Find and display Loyola College Maryland

# %%
df_new[df_new['INSTNM'].str.contains('Loyola')&df_new['INSTNM'].str.contains('Maryland')]
# Out:
#       UNITID                      INSTNM       CITY STABBR         ZIP  \
# 1775  163046  Loyola University Maryland  Baltimore     MD  21210-2699
#
#       ADM_RATE    UGDS  TUITIONFEE_IN MN_EARN_WNE_P10
# 1775     0.598  3560.0        34250.0           79300

# %% [markdown]
# ### Find and display Johns Hopskins

# %%
df_new[df_new['INSTNM'].str.contains('Johns Hopkins')]
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1772  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN MN_EARN_WNE_P10
# 1772    0.2571  5534.0        35900.0           84200

# %% [markdown]
# ### Calculate the min, max, and average in-state tution of the above four institutions.

# %%
df_new[df_new['UNITID'].isin([162928, 163046, 163268, 163286])]
# Out:
#       UNITID                                   INSTNM          CITY STABBR  \
# 1772  162928                 Johns Hopkins University     Baltimore     MD
# 1775  163046               Loyola University Maryland     Baltimore     MD
# 1779  163268  University of Maryland-Baltimore County     Baltimore     MD
# 1780  163286      University of Maryland-College Park  College Park     MD
#
#              ZIP  ADM_RATE     UGDS  TUITIONFEE_IN MN_EARN_WNE_P10
# 1772  21218-2688    0.2571   5534.0        35900.0           84200
# 1775  21210-2699    0.5980   3560.0        34250.0           79300
# 1779       21250    0.6895   9304.0         8708.0           58000
# 1780       20742    0.4704  25295.0         7969.0           66700

# %%
Institute_4 = df_new[df_new['UNITID'].isin([162928, 163046, 163268, 163286])]
print(Institute_4[Institute_4.TUITIONFEE_IN == Institute_4.TUITIONFEE_IN.min()])
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1780  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN MN_EARN_WNE_P10
# 1780    0.4704  25295.0         7969.0           66700

# %%
print(Institute_4[Institute_4.TUITIONFEE_IN == Institute_4.TUITIONFEE_IN.max()])
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1772  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN MN_EARN_WNE_P10
# 1772    0.2571  5534.0        35900.0           84200

# %%
Institute_4['TUITIONFEE_IN'].mean()
# Out:
# 21706.75

# %% [markdown]
# ### 11. Filter the smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia. Save the filtered dataset to a new file named "Five_States_Colleges.csv" for future analysis. Upload this file to your GitHub along with the notebook.

# %%
Five_States_Colleges = df_new[df_new['STABBR'].isin(['MD', 'VA', 'DC', 'DE','PA'])]

# %%
Five_States_Colleges
# Out:
#         UNITID                                             INSTNM  \
# 747     130837  Margaret H Rollins School of Nursing at Beebe ...
# 748     130873                          Dawn Career Institute LLC
# 749     130891         Delaware Technical Community College-Owens
# 750     130907         Delaware Technical Community College-Terry
# 751     130916  Delaware Technical Community College-Stanton/W...
# ...        ...                                                ...
# 6938  21599201               Laurel Technical Institute Meadville
# 6939  21608301  South Hills School of Business and Technology-...
# 6963  43821201             McCann School of Business & Technology
# 6964  43821202             McCann School of Business & Technology
# 6965  43821203             McCann School of Business & Technology
#
#                 CITY STABBR        ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  \
# 747            Lewes     DE      19958       NaN    41.0            NaN
# 748           Newark     DE      19702       1.0   317.0            NaN
# 749       Georgetown     DE      19947       NaN  3714.0         2490.0
# 750            Dover     DE      19901       NaN  2902.0         2490.0
# 751       Wilmington     DE      19801       NaN  6909.0         2490.0
# ...              ...    ...        ...       ...     ...            ...
# 6938       Meadville     PA  163352754       NaN     NaN         8600.0
# 6939         Altoona     PA      16602       NaN     NaN        12294.0
# 6963  Hazle Township     PA      18202       NaN     NaN        10896.0
# 6964       Lewisburg     PA      17837       NaN     NaN        10896.0
# 6965    Dickson City     PA      18519       NaN     NaN        10896.0
#
#         MN_EARN_WNE_P10
# 747   PrivacySuppressed
# 748               29000
# 749               32700
# 750               33400
# 751               38600
# ...                 ...
# 6938              22600
# 6939              30500
# 6963              27000
# 6964              27000
# 6965              27000
#
# [703 rows x 9 columns]

# %%
Five_States_Colleges.to_csv('Five_States_Colleges.csv')
